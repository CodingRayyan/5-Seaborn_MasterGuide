# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, style = 'size')
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, style = 'smoker')
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
tips['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %% [markdown]
# ###
# ## Setting size limit
# ###

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, style = 'size')
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, size = 'size', sizes = (15, 200))
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, size = 'time', sizes = (15, 250))
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ###
# ## Setting Colours for hue
# ###

# %%
import seaborn as sns
import pandas as pd

tips = sns.load_dataset('tips')
tips

colours = { 'Lunch' : 'Blue' , 'Dinner' : 'Green'}

sns.relplot( x = 'total_bill', y = 'tip', data = tips, hue = 'time', palette = colours)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ###
# ## Setting Style of Our Own Choice
# ###

# %%
import seaborn as sns
import pandas as pd

a = sns.load_dataset('tips')

colours = ['blue','orange','green','red']
styles = {'Lunch' : 's' , 'Dinner' : 'o'}
sns.relplot( x = 'total_bill', y = 'tip', data = a, hue = 'day', palette = colours, style = 'time', markers = styles, size = 'sex', sizes = (15,100))
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ###
# ## Using col
# col_wrap means no. of coulmns
#
# ###

# %%
import seaborn as sns
import pandas as pd

a = sns.load_dataset('tips')

colours = ['blue','orange','green','red']
styles = {'Lunch' : 's' , 'Dinner' : 'o'}
sns.relplot( x = 'total_bill', y = 'tip', data = a, hue = 'day', palette = colours, style = 'time', markers = styles, size = 'sex', sizes = (15,100), col = 'smoker', col_wrap = 2)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ###
# ## Using col
# ###

# %%
import seaborn as sns
import pandas as pd

a = sns.load_dataset('tips')

colours = ['blue','orange','green','red']
styles = {'Lunch' : 's' , 'Dinner' : 'o'}
sns.relplot( x = 'total_bill', y = 'tip', data = a, hue = 'smoker', palette = colours, style = 'time', markers = styles, size = 'sex', sizes = (15,100), col = 'day', col_wrap = 2)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12828\1576896557.py:10: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.relplot( x = 'total_bill', y = 'tip', data = a, hue = 'smoker', palette = colours, style = 'time', markers = styles, size = 'sex', sizes = (15,100), col = 'day', col_wrap = 2)
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
